# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
from PIL import Image
import numpy as np
import pandas as pd
import os
import sys
from sklearn.model_selection import train_test_split

# %%
mask_folder = os.path.join('AUG-Train', 'Train-Mask')
nomask_folder = os.path.join('AUG-Train', 'Train-NoMask')

# %%
maskpath, nomaskpath = [], []
for root, dirs, files in os.walk("AUG-Train"):
    for file in files:
        if file[:4] == 'mask':
            maskpath.append([os.path.join(root, file), 1])
        elif file[:2] == 'no':
            nomaskpath.append([os.path.join(root, file), 0])

# %%
data = []
image_size = 100
for i in nomaskpath + maskpath:
    img_array = cv2.imread(i[0])   # Uses BGR instead of RGB, have to change it back
    img_array = cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB) # Converts to correct image encoding
    new_img_array = cv2.resize(img_array, (image_size, image_size))      # resizing the image array
    
    # encoding the labels. with_mask = 1 and without_mask = 0
    if i[1] == 1:
        data.append([new_img_array, 1])
    else:
        data.append([new_img_array, 0])

# %%
x = []
y = []
for image in data:
    x.append(image[0])
    y.append(image[1])

# converting x & y to numpy array as they are list
x = np.array(x)
y = np.array(y)

# %%
x = x/255

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y)

# %%
# Defining the model
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=X_train[0].shape),    # flattening the image
    tf.keras.layers.Dense(50, activation='relu'),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(50, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])


lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=0.9)

optimizer = tf.keras.optimizers.Adagrad(learning_rate=lr_schedule)

model.compile(optimizer=optimizer,
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=200, batch_size = int(0.08 * len(X_train)))
# Out:
# Epoch 1/200
# 13/13 [==============================] - 0s 17ms/step - loss: 1.1536 - accuracy: 0.5258
# Epoch 2/200
# 13/13 [==============================] - 0s 23ms/step - loss: 0.6515 - accuracy: 0.5925
# Epoch 3/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.6391 - accuracy: 0.6420
# Epoch 4/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.6401 - accuracy: 0.6298
# Epoch 5/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.5966 - accuracy: 0.6927
# Epoch 6/200
# 13/13 [==============================] - 0s 33ms/step - loss: 0.6998 - accuracy: 0.5362
# Epoch 7/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.6596 - accuracy: 0.6532
# Epoch 8/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.6435 - accuracy: 0.6485
# Epoch 9/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.5734 - accuracy: 0.6918
# Epoch 10/200
# 13/13 [==============================] - 0s 22ms/step - loss: 0.5692 - accuracy: 0.7139
# Epoch 11/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.5082 - accuracy: 0.7564
# Epoch 12/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.4872 - accuracy: 0.7811
# Epoch 13/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.4770 - accuracy: 0.7698
# Epoch 14/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.4602 - accuracy: 0.7807
# Epoch 15/200
# 13/13 [==============================] - 0s 22ms/step - loss: 0.4647 - accuracy: 0.7828
# Epoch 16/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.4332 - accuracy: 0.7876
# Epoch 17/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.4433 - accuracy: 0.7980
# Epoch 18/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.3277 - accuracy: 0.8539
# Epoch 19/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.4373 - accuracy: 0.8006
# Epoch 20/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.3128 - accuracy: 0.8661
# Epoch 21/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.3620 - accuracy: 0.8396
# Epoch 22/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.3720 - accuracy: 0.8253
# Epoch 23/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.2748 - accuracy: 0.8821
# Epoch 24/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0
200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.4997 - accuracy: 0.8140
# Epoch 66/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.3499 - accuracy: 0.8587
# Epoch 67/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1366 - accuracy: 0.9493
# Epoch 68/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1212 - accuracy: 0.9532
# Epoch 69/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1308 - accuracy: 0.9458
# Epoch 70/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1144 - accuracy: 0.9541
# Epoch 71/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1185 - accuracy: 0.9515
# Epoch 72/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1161 - accuracy: 0.9515
# Epoch 73/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.1056 - accuracy: 0.9571
# Epoch 74/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.3147 - accuracy: 0.8873
# Epoch 75/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.3439 - accuracy: 0.8635
# Epoch 76/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.3259 - accuracy: 0.8721
# Epoch 77/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1155 - accuracy: 0.9510
# Epoch 78/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1088 - accuracy: 0.9554
# Epoch 79/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.1079 - accuracy: 0.9541
# Epoch 80/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1020 - accuracy: 0.9571
# Epoch 81/200
# 13/13 [==============================] - 0s 21ms/step - loss: 0.1035 - accuracy: 0.9567
# Epoch 82/200
# 13/13 [==============================] - 0s 26ms/step - loss: 0.0976 - accuracy: 0.9601
# Epoch 83/200
# 13/13 [==============================] - 0s 24ms/step - loss: 0.1009 - accuracy: 0.9606
# Epoch 84/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0979 - accuracy: 0.9571
# Epoch 85/200
# 13/13 [==============================] - 0s 21ms/step - loss: 0.1050 - accuracy: 0.9554
# Epoch 86/200
# 13/13 [==============================] - 0s 21ms/step - loss: 0.1428 - accuracy: 0.9306
# Epoch 87/200
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0917 - accuracy: 0.9619
# Epoch 88/200
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0859 - accuracy: 0.9610
# Epoch 89/200
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0862 - accuracy: 0.9640
# Epoch 90/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0832 - accuracy: 0.9692
# Epoch 91/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0868 - accuracy: 0.9649
# Epoch 92/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.3984 - accuracy: 0.8262
# Epoch 93/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.1204 - accuracy: 0.9541
# Epoch 94/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0866 - accuracy: 0.9627
# Epoch 95/200
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0816 - accuracy: 0.9666
# Epoch 96/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0792 - accuracy: 0.9658
# Epoch 97/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0797 - accuracy: 0.9658
# Epoch 98/200
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0767 - accuracy: 0.9692
# Epoch 99/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.1070 - accuracy: 0.9545
# Epoch 100/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0765 - accuracy: 0.9666
# Epoch 101/200
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0786 - accuracy: 0.9649
# Epoch 102/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0757 - accuracy: 0.9675
# Epoch 103/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0797 - accuracy: 0.9658
# Epoch 104/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.3194 - accuracy: 0.8786
# Epoch 105/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0802 - accuracy: 0.9666
# Epoch 106/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1030 - accuracy: 0.9532
# Epoch 107/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0737 - accuracy: 0.9701
# Epoch 108/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0756 - accuracy: 0.9710
# Epoch 109/200
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0789 - accuracy: 0.9662
# Epoch 110/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0812 - accuracy: 0.9632
# Epoch 111/200
# 13/13 [==============================] - 0s 20ms/step - loss: 0.2954 - accuracy: 0.8669
# Epoch 112/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0858 - accuracy: 0.9645
# Epoch 113/200
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0687 - accuracy: 0.9697
# Epoch 114/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0647 - accuracy: 0.9731
# Epoch 115/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0618 - accuracy: 0.9749
# Epoch 116/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0606 - accuracy: 0.9766
# Epoch 117/200
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0586 - accuracy: 0.9792
# Epoch 118/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0610 - accuracy: 0.9757
# Epoch 119/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0569 - accuracy: 0.9788
# Epoch 120/200
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0564 - accuracy: 0.9788
# Epoch 121/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0571 - accuracy: 0.9770
# Epoch 122/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0550 - accuracy: 0.9792
# Epoch 123/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1009 - accuracy: 0.9541
# Epoch 124/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0568 - accuracy: 0.9770
# Epoch 125/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0557 - accuracy: 0.9796
# Epoch 126/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0605 - accuracy: 0.9757
# Epoch 127/200
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0588 - accuracy: 0.9788
# Epoch 128/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.3381 - accuracy: 0.8548
# Epoch 129/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.5469 - accuracy: 0.8834
# Epoch 130/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.2774 - accuracy: 0.9120
# Epoch 131/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.2196 - accuracy: 0.9202
# Epoch 132/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.2866 - accuracy: 0.8886
# Epoch 133/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.2996 - accuracy: 0.9120
# Epoch 134/200
# 13/13 [==============================] - 0s 20ms/step - loss: 0.1674 - accuracy: 0.9397
# Epoch 135/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.4118 - accuracy: 0.8596
# Epoch 136/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.2467 - accuracy: 0.9332
# Epoch 137/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.3169 - accuracy: 0.8895
# Epoch 138/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.1488 - accuracy: 0.9519
# Epoch 139/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.4326 - accuracy: 0.8613
# Epoch 140/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1680 - accuracy: 0.9480
# Epoch 141/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.4345 - accuracy: 0.8782
# Epoch 142/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.1609 - accuracy: 0.9497
# Epoch 143/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1278 - accuracy: 0.9528
# Epoch 144/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.3384 - accuracy: 0.8786
# Epoch 145/200
# 13/13 [==============================] - 0s 20ms/step - loss: 0.1309 - accuracy: 0.9549
# Epoch 146/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.3905 - accuracy: 0.8704
# Epoch 147/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1590 - accuracy: 0.9523
# Epoch 148/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.1308 - accuracy: 0.9502
# Epoch 149/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.1358 - accuracy: 0.9406
# Epoch 150/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.2697 - accuracy: 0.9020
# Epoch 151/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1111 - accuracy: 0.9619
# Epoch 152/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1273 - accuracy: 0.9515
# Epoch 153/200
# 13/13 [==============================] - 0s 21ms/step - loss: 0.1043 - accuracy: 0.9640
# Epoch 154/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0934 - accuracy: 0.9658
# Epoch 155/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.1628 - accuracy: 0.9358
# Epoch 156/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0939 - accuracy: 0.9610
# Epoch 157/200
# 13/13 [==============================] - 0s 22ms/step - loss: 0.4540 - accuracy: 0.8661
# Epoch 158/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.1310 - accuracy: 0.9575
# Epoch 159/200
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0926 - accuracy: 0.9675
# Epoch 160/200
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0907 - accuracy: 0.9679
# Epoch 161/200
# 13/13 [==============================] - 0s 20ms/step - loss: 0.5307 - accuracy: 0.8301
# Epoch 162/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1766 - accuracy: 0.9528
# Epoch 163/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1028 - accuracy: 0.9632
# Epoch 164/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0865 - accuracy: 0.9679
# Epoch 165/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0891 - accuracy: 0.9684
# Epoch 166/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0795 - accuracy: 0.9718
# Epoch 167/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0825 - accuracy: 0.9675
# Epoch 168/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0717 - accuracy: 0.9753
# Epoch 169/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.3171 - accuracy: 0.9129
# Epoch 170/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.1302 - accuracy: 0.9554
# Epoch 171/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0765 - accuracy: 0.9779
# Epoch 172/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0722 - accuracy: 0.9766
# Epoch 173/200
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0791 - accuracy: 0.9714
# Epoch 174/200
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0713 - accuracy: 0.9757
# Epoch 175/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0733 - accuracy: 0.9705
# Epoch 176/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0700 - accuracy: 0.9775
# Epoch 177/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0630 - accuracy: 0.9801
# Epoch 178/200
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0622 - accuracy: 0.9796
# Epoch 179/200
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0895 - accuracy: 0.9649
# Epoch 180/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.4001 - accuracy: 0.8994
# Epoch 181/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0686 - accuracy: 0.9792
# Epoch 182/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0634 - accuracy: 0.9792
# Epoch 183/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0621 - accuracy: 0.9809
# Epoch 184/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0600 - accuracy: 0.9796
# Epoch 185/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0809 - accuracy: 0.9705
# Epoch 186/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0570 - accuracy: 0.9822
# Epoch 187/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0553 - accuracy: 0.9831
# Epoch 188/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0513 - accuracy: 0.9840
# Epoch 189/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0641 - accuracy: 0.9749
# Epoch 190/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.4985 - accuracy: 0.8500
# Epoch 191/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0972 - accuracy: 0.9671
# Epoch 192/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0786 - accuracy: 0.9718
# Epoch 193/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0777 - accuracy: 0.9679
# Epoch 194/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0733 - accuracy: 0.9688
# Epoch 195/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0703 - accuracy: 0.9727
# Epoch 196/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0750 - accuracy: 0.9718
# Epoch 197/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1129 - accuracy: 0.9545
# Epoch 198/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0634 - accuracy: 0.9762
# Epoch 199/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0656 - accuracy: 0.9744
# Epoch 200/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.1561 - accuracy: 0.9389

# %%
model.evaluate(X_test, y_test)
# Out:
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1073 - accuracy: 0.9558
# [0.10726340860128403, 0.9558441638946533]

# %%
len(X_train)
# Out:
# 2307

# %% [markdown]
# ## Bring in test dataset

# %%
test_mask_path, test_nomask_path = [], []
for root, dirs, files in os.walk(os.path.join('test', 'with_mask')):
    for file in files:
        test_mask_path.append([os.path.join('test', 'with_mask',  file), 1])
for root, dirs, files in os.walk(os.path.join('test', 'without_mask')):
    for file in files:
        test_nomask_path.append([os.path.join('test', 'without_mask',  file),0])

# %%
testdata = []
image_size = 100
for i in test_mask_path+test_nomask_path:
    img_array = cv2.imread(i[0])   # Uses BGR instead of RGB, have to change it back
    img_array = cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB) # Converts to correct image encoding
    new_img_array = cv2.resize(img_array, (image_size, image_size))      # resizing the image array
    
    # encoding the labels. with_mask = 1 and without_mask = 0
    if i[1] == 1:
        testdata.append([new_img_array, 1])
    else:
        testdata.append([new_img_array, 0])

# %%
x_test = []
y_test = []
for image in testdata:
    x_test.append(image[0])
    y_test.append(image[1])

# converting x & y to numpy array as they are list
x_test = np.array(x_test)
y_test = np.array(y_test)

# %%
x_test = x_test / 255

# %%
model.evaluate(x_test, y_test)
# Out:
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2205 - accuracy: 0.8939
# [0.22053322196006775, 0.8939393758773804]
